# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('train1.csv', index_col=0)
df
# Out:
#                                          full_name     sex birth_year  \
# id
# 8729                              Nikita Mikhalkov    Male       1945
# 1462                                Uesugi Kenshin    Male       1530
# 10135                               Pope Hormisdas    Male        450
# 1126                           Mohammad Najibullah    Male       1947
# 1534                       André Frédéric Cournand    Male       1895
# 2799                                Rodrigo Taddei    Male       1980
# 7747                                Mari Kiviniemi  Female       1968
# 164                              John II of France    Male       1319
# 3479                                  Jean Fouquet    Male       1420
# 5024                                         Hergé    Male       1907
# 9482                        William Lawrence Bragg    Male       1890
# 8545                                 Luis Barragán    Male       1902
# ...

# %%
# List of columns
df.columns
# Out:
# Index(['id', 'full_name', 'sex', 'birth_year', 'city', 'state', 'country',
#        'continent', 'latitude', 'longitude', 'occupation', 'industry',
#        'domain', 'article_languages', 'page_views', 'average_views',
#        'historical_popularity_index'],
#       dtype='object')

# %%
# Data types of columns
df.dtypes
# Out:
# id                               int64
# full_name                       object
# sex                             object
# birth_year                      object
# city                            object
# state                           object
# country                         object
# continent                       object
# latitude                       float64
# longitude                      float64
# occupation                      object
# industry                        object
# domain                          object
# article_languages                int64
# page_views                       int64
# average_views                    int64
# historical_popularity_index    float64
# dtype: object

# %%
df['state'].value_counts()
# Out:
# 6

# %%
test = pd.read_csv("test.csv", index_col=0)
print(test.dtypes)
test.head()
# Out:
# full_name             object
# sex                   object
# birth_year             int64
# city                  object
# state                 object
# country               object
# continent             object
# latitude             float64
# longitude            float64
# occupation            object
# industry              object
# domain                object
# article_languages      int64
# page_views             int64
# average_views          int64
# dtype: object
#                            full_name   sex  birth_year       city state  \
# id
# 6217                 Vidkun Quisling  Male        1887   Fyresdal   NaN
# 3763  Charles Louis Alphonse Laveran  Male        1845      Paris   NaN
# 4990                    John Goodman  Male        1952  St. Louis    MO
# 7714                  Eugen d'Albert  Male        1864    Glasgow   NaN
# 6032                       Max Bruch  Male        1838    Cologne   NaN
#
# ...

# %%
y = df['historical_popularity_index']
X = df[['page_views','average_views', 'article_languages']]
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model = LinearRegression()
for i in range(4):
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    model.fit(X_train, y_train) # acutal training
    print(model.score(X_test, y_test))
# Out:
# 0.22989713024
# 0.25178025328
# 0.264137205983
# 0.239385614232

# %%
model.fit(X, y)
test['historical_popularity_index'] = model.predict(test[['page_views', 'average_views', 'article_languages']].values)
test
# Out:
#                              full_name     sex  birth_year  \
# id
# 6217                   Vidkun Quisling    Male        1887
# 3763    Charles Louis Alphonse Laveran    Male        1845
# 4990                      John Goodman    Male        1952
# 7714                    Eugen d'Albert    Male        1864
# 6032                         Max Bruch    Male        1838
# 9480          Christoph Martin Wieland    Male        1733
# 8052                      Edgar Davids    Male        1973
# 6766                 Albert Kesselring    Male        1885
# 4109                   Judas Maccabeus    Male         100
# 6958           Frederick IX of Denmark    Male        1899
# 2505                    Guido d'Arezzo    Male         991
# 7206                Katharina von Bora  Female        1499
# 10198                   Andrew Carroll    Male        1989
# 5328                        Uli Hoeneß    Male        1952
# 399                         Ian McEwan    Male        1948
# ...

# %%
test[['historical_popularity_index']].to_csv('sample_submission.csv')

# %%
df['birth_year'] = df['birth_year'].apply(pd.to_numeric, errors='coerce')
df['birth_year'] = df['birth_year'].fillna(0)
print(df.dtypes)
df.head()
# Out:
# id                               int64
# id.1                             int64
# full_name                       object
# sex                             object
# birth_year                     float64
# city                            object
# state                           object
# country                         object
# continent                       object
# latitude                       float64
# longitude                      float64
# occupation                      object
# industry                        object
# domain                          object
# article_languages                int64
# page_views                       int64
# average_views                    int64
# historical_popularity_index    float64
# dtype: object
#      id  id.1               full_name   sex  birth_year        city state  \
# 0  4110  3728            Gao Xingjian  Male      1940.0     Ganzhou   NaN
# 1  8160  3769        Wassily Leontief  Male      1905.0      Munich   NaN
# ...

# %%
y = df['historical_popularity_index']
X = df[['page_views','average_views', 'article_languages', 'birth_year']]
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.39777899828372892

# %%
df.head()
# Out:
#      id  id.1               full_name   sex  birth_year        city state  \
# 0  4110  3728            Gao Xingjian  Male      1940.0     Ganzhou   NaN
# 1  8160  3769        Wassily Leontief  Male      1905.0      Munich   NaN
# 2  4927  1777       Justus von Liebig  Male      1803.0   Darmstadt   NaN
# 3  3031  5856  William Stanley Jevons  Male      1835.0   Liverpool   NaN
# 4  7267    58          Thomas Aquinas  Male      1225.0  Roccasecca   NaN
#
#           country continent  latitude  longitude   occupation  \
# 0           China      Asia  25.86667  114.93333       Writer
# 1         Germany    Europe  48.13333   11.56667    Economist
# 2         Germany    Europe  49.86667    8.65000      Chemist
# 3  United Kingdom    Europe  53.40000   -3.00000    Economist
# 4           Italy    Europe  41.55000   13.66667  Philosopher
#
#            industry                domain  article_languages  page_views  \
# ...

# %%
df = df.drop(df.columns[2:-1], axis=1)

# %%
df.head()
# Out:
#      id               full_name   sex  birth_year        city state  \
# 0  4110            Gao Xingjian  Male      1940.0     Ganzhou   NaN
# 1  8160        Wassily Leontief  Male      1905.0      Munich   NaN
# 2  4927       Justus von Liebig  Male      1803.0   Darmstadt   NaN
# 3  3031  William Stanley Jevons  Male      1835.0   Liverpool   NaN
# 4  7267          Thomas Aquinas  Male      1225.0  Roccasecca   NaN
#
#           country continent  latitude  longitude   occupation  \
# 0           China      Asia  25.86667  114.93333       Writer
# 1         Germany    Europe  48.13333   11.56667    Economist
# 2         Germany    Europe  49.86667    8.65000      Chemist
# 3  United Kingdom    Europe  53.40000   -3.00000    Economist
# 4           Italy    Europe  41.55000   13.66667  Philosopher
#
#            industry                domain  article_languages  page_views  \
# 0          Language            Humanities                 63     1439340
# ...
